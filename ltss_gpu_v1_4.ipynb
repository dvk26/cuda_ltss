# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_gpu_v1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 337, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 337 (delta 108), reused 146 (delta 57), pack-reused 138 (from 1)
# Receiving objects: 100% (337/337), 169.89 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# AGENTS.md	     ltss_gpu_v1_3.ipynb  prompts	train-svm.ipynb
# documents	     ltss_gpu_v1_4.ipynb  README.md
# ltss_gpu.ipynb	     ltss_gpu_v2_1.ipynb  Report.ipynb
# ltss_gpu_v1_1.ipynb  ltss_gpu_v2.ipynb	  src

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -std=c++17 -O2 src/gpu_v1.4/main.cu src/gpu_v1.4/gpu_autoencoder.cu -I./src/gpu_v1.4 -arch=sm_75 -o autoencoder_gpu_v1.4

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-17 15:08:38--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  12.6MB/s    in 33s
#
# 2025-12-17 15:09:12 (4.84 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !./autoencoder_gpu_v1.4 cifar-10-batches-bin --keep-partial
# Out:
# Loading CIFAR-10...
# Total images: 2400 (train 2000, test 400)
# Starting training v1.4 (Full GPU Pipeline)...
# [Epoch 1/20] Batch 30/32 | Loss: 0.1947
#    -> Time: 22.0796s (1.4 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 2/20] Batch 30/32 | Loss: 0.0946
#    -> Time: 22.3385s (1.4 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 3/20] Batch 30/32 | Loss: 0.0749
#    -> Time: 22.7211s (1.4 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 4/20] Batch 30/32 | Loss: 0.0642
#    -> Time: 23.1500s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 5/20] Batch 30/32 | Loss: 0.0571
#    -> Time: 23.6609s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 6/20] Batch 30/32 | Loss: 0.0523
#    -> Time: 23.7281s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 7/20] Batch 30/32 | Loss: 0.0487
#    -> Time: 23.4659s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 8/20] Batch 30/32 | Loss: 0.0456
#    -> Time: 23.3758s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 9/20] Batch 30/32 | Loss: 0.0432
#    -> Time: 23.4835s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 10/20] Batch 30/32 | Loss: 0.0413
#    -> Time: 23.5255s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 11/20] Batch 30/32 | Loss: 0.0397
#    -> Time: 23.4843s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 12/20] Batch 30/32 | Loss: 0.0382
#    -> Time: 23.4367s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 13/20] Batch 30/32 | Loss: 0.0370
#    -> Time: 23.4282s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 14/20] Batch 30/32 | Loss: 0.0359
#    -> Time: 23.4345s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 15/20] Batch 30/32 | Loss: 0.0350
#    -> Time: 23.4384s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 16/20] Batch 30/32 | Loss: 0.0340
#    -> Time: 23.4662s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 17/20] Batch 30/32 | Loss: 0.0332
#    -> Time: 23.4858s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 18/20] Batch 30/32 | Loss: 0.0326
#    -> Time: 23.4948s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 19/20] Batch 30/32 | Loss: 0.0319
#    -> Time: 23.4966s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 20/20] Batch 30/32 | Loss: 0.0313
#    -> Time: 23.5087s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
#
# === Final Test Evaluation ===
# Final Test MSE Loss: 0.03
# Done. Check ./out-gpu-v1.4 for weights.

# %%
# !mkdir -p /content/drive/MyDrive/cuda_ltss/weights

# %%
# !cp -r /content/cuda_ltss/out-gpu-v1.4 /content/drive/MyDrive/cuda_ltss/weights

# %% [markdown]
# - Trọng số mô hình được lưu ở đây: https://drive.google.com/drive/folders/1NyNufArwusMGBTC_hb3nvjpZR9F2CcUa?usp=sharing
