# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_gpu_v1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 386, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 386 (delta 131), reused 186 (delta 70), pack-reused 138 (from 1)
# Receiving objects: 100% (386/386), 170.28 MiB | 26.65 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# AGENTS.md			     ltss_gpu_v1_1.ipynb  README.md
# documents			     ltss_gpu_v1_3.ipynb  Report.ipynb
# extract_feature_and_train_svm.ipynb  ltss_gpu_v1_4.ipynb  src
# ltss_gpu.ipynb			     prompts		  train_svm.ipynb

# %%
# !git checkout anhkhoi-branch
# Out:
# Branch 'anhkhoi-branch' set up to track remote branch 'anhkhoi-branch' from 'origin'.
# Switched to a new branch 'anhkhoi-branch'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -std=c++17 -O2 src/gpu_v1.4/main.cu src/gpu_v1.4/gpu_autoencoder.cu -I./src/gpu_v1.4 -arch=sm_75 -o autoencoder_gpu_v1.4

# %%
# !nvcc -std=c++17 -O2 src/gpu_v1.3/main.cu src/gpu_v1.3/gpu_autoencoder.cu -I./src/gpu_v1.3 -arch=sm_75 -o autoencoder_gpu_v1.3

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-18 06:05:55--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  44.9MB/s    in 4.0s
#
# 2025-12-18 06:06:00 (40.4 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !./autoencoder_gpu_v1.4 cifar-10-batches-bin --keep-partial
# Out:
# Loading CIFAR-10...
# Total images: 2400 (train 2000, test 400)
# Starting training v1.4 (Full GPU Pipeline)...
# [Epoch 1/20] Batch 30/32 | Loss: 0.1983
#    -> Time: 22.2943s (1.4 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 2/20] Batch 30/32 | Loss: 0.0947
#    -> Time: 22.5564s (1.4 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 3/20] Batch 30/32 | Loss: 0.0747
#    -> Time: 23.0238s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 4/20] Batch 30/32 | Loss: 0.0643
#    -> Time: 23.5552s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 5/20] Batch 30/32 | Loss: 0.0571
#    -> Time: 23.9028s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 6/20] Batch 30/32 | Loss: 0.0522
#    -> Time: 23.5735s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 7/20] Batch 30/32 | Loss: 0.0484
#    -> Time: 23.5313s (1.3 batches/s)
#    -> Peak VRAM: 456.94 MiB
# [Epoch 8/20] Batch 30/32 | Loss: 0.0455
#    -> Time: 23.6600s (1.3 batches/s)
# ...

# %%
# !mkdir -p /content/drive/MyDrive/cuda_ltss/weights

# %%
# !cp -r /content/cuda_ltss/out-gpu-v1.4 /content/drive/MyDrive/cuda_ltss/weights

# %% [markdown]
# - Trọng số mô hình được lưu ở đây: https://drive.google.com/drive/folders/1NyNufArwusMGBTC_hb3nvjpZR9F2CcUa?usp=sharing

# %%
# !./autoencoder_gpu_v1.3 cifar-10-batches-bin --keep-partial
# Out:
# Loading CIFAR-10...
# Total images: 2400 (train 2000, test 400)
# Starting training v1.3...
# [Epoch 1/20] Batch 30/32 | Loss: 0.1975
#    -> Time: 21.7372s (1.4 batches/s)
# [Epoch 2/20] Batch 30/32 | Loss: 0.0948
#    -> Time: 22.2019s (1.4 batches/s)
# [Epoch 3/20] Batch 30/32 | Loss: 0.0750
#    -> Time: 22.2826s (1.4 batches/s)
# [Epoch 4/20] Batch 30/32 | Loss: 0.0643
#    -> Time: 21.9332s (1.4 batches/s)
# [Epoch 5/20] Batch 30/32 | Loss: 0.0572
#    -> Time: 21.9426s (1.4 batches/s)
# [Epoch 6/20] Batch 30/32 | Loss: 0.0523
#    -> Time: 22.0693s (1.4 batches/s)
# [Epoch 7/20] Batch 30/32 | Loss: 0.0485
#    -> Time: 22.0467s (1.4 batches/s)
# [Epoch 8/20] Batch 30/32 | Loss: 0.0456
#    -> Time: 21.9958s (1.4 batches/s)
# [Epoch 9/20] Batch 30/32 | Loss: 0.0432
#    -> Time: 21.9804s (1.4 batches/s)
# [Epoch 10/20] Batch 30/32 | Loss: 0.0413
#    -> Time: 22.0235s (1.4 batches/s)
# [Epoch 11/20] Batch 30/32 | Loss: 0.0396
#    -> Time: 22.0306s (1.4 batches/s)
# ...

# %%
# !./autoencoder_gpu_v1.4 cifar-10-batches-bin --keep-partial
# Out:
# Loading CIFAR-10...
# Total images: 2400 (train 2000, test 400)
# Starting training v1.4...
# [Epoch 1/20] Batch 10/16 | Loss: 0.3118
#    -> Time: 22.0777s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 2/20] Batch 10/16 | Loss: 0.1327
#    -> Time: 22.5659s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 3/20] Batch 10/16 | Loss: 0.1058
#    -> Time: 23.1246s (0.6 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 4/20] Batch 10/16 | Loss: 0.0913
#    -> Time: 22.7684s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 5/20] Batch 10/16 | Loss: 0.0815
#    -> Time: 22.5351s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 6/20] Batch 10/16 | Loss: 0.0736
#    -> Time: 22.6596s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 7/20] Batch 10/16 | Loss: 0.0679
#    -> Time: 22.7793s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# [Epoch 8/20] Batch 10/16 | Loss: 0.0643
#    -> Time: 22.7062s (0.7 batches/s)
#    -> Peak VRAM: 516.94 MiB
# ...
