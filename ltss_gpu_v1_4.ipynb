# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_gpu_v1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 195 (delta 31), reused 44 (delta 18), pack-reused 138 (from 1)
# Receiving objects: 100% (195/195), 161.80 MiB | 6.97 MiB/s, done.
# Resolving deltas: 100% (106/106), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# ltss_gpu.ipynb	     ltss_gpu_v2.ipynb	Report.ipynb
# ltss_gpu_v2_1.ipynb  README.md		src

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -std=c++17 -O2 \
    src/gpu_v1.3/main.cu \
    src/gpu_v1.3/gpu_autoencoder.cu \
    -I./include \
    -arch=sm_75 \
    -o autoencoder_gpu_v1.3

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-11 16:52:10--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  49.7MB/s    in 3.6s
#
# 2025-12-11 16:52:14 (45.0 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !./autoencoder_gpu_v1.3 cifar-10-batches-bin
# Out:
# Loading CIFAR-10...
# Total images: 60000 (train 50000, test 10000)
# Starting training v1.4 (Full GPU Pipeline)...
# [Epoch 1/20] Batch 780/782 | Loss: 0.0481
#    -> Time: 548.0643s (1.4 batches/s)
# [Epoch 2/20] Batch 780/782 | Loss: 0.0251
#    -> Time: 551.9452s (1.4 batches/s)
# [Epoch 3/20] Batch 780/782 | Loss: 0.0211
#    -> Time: 551.4278s (1.4 batches/s)
# [Epoch 4/20] Batch 780/782 | Loss: 0.0189
#    -> Time: 551.1717s (1.4 batches/s)
# [Epoch 5/20] Batch 780/782 | Loss: 0.0175
#    -> Time: 551.2507s (1.4 batches/s)
# [Epoch 6/20] Batch 780/782 | Loss: 0.0165
#    -> Time: 550.6394s (1.4 batches/s)
# [Epoch 7/20] Batch 780/782 | Loss: 0.0157
#    -> Time: 550.3089s (1.4 batches/s)
# [Epoch 8/20] Batch 780/782 | Loss: 0.0151
#    -> Time: 550.2952s (1.4 batches/s)
# [Epoch 9/20] Batch 780/782 | Loss: 0.0146
#    -> Time: 550.1324s (1.4 batches/s)
# [Epoch 10/20] Batch 780/782 | Loss: 0.0141
#    -> Time: 550.2047s (1.4 batches/s)
# [Epoch 11/20] Batch 780/782 | Loss: 0.0138
#    -> Time: 550.5047s (1.4 batches/s)
# [Epoch 12/20] Batch 780/782 | Loss: 0.0134
#    -> Time: 550.4186s (1.4 batches/s)
# [Epoch 13/20] Batch 780/782 | Loss: 0.0132
#    -> Time: 550.4780s (1.4 batches/s)
# [Epoch 14/20] Batch 780/782 | Loss: 0.0129
#    -> Time: 550.5309s (1.4 batches/s)
# [Epoch 15/20] Batch 780/782 | Loss: 0.0127
#    -> Time: 550.6772s (1.4 batches/s)
# [Epoch 16/20] Batch 780/782 | Loss: 0.0124
#    -> Time: 550.5259s (1.4 batches/s)
# [Epoch 17/20] Batch 780/782 | Loss: 0.0123
#    -> Time: 550.0660s (1.4 batches/s)
# [Epoch 18/20] Batch 780/782 | Loss: 0.0121
#    -> Time: 549.8797s (1.4 batches/s)
# [Epoch 19/20] Batch 780/782 | Loss: 0.0119
#    -> Time: 550.0973s (1.4 batches/s)
# [Epoch 20/20] Batch 780/782 | Loss: 0.0117
#    -> Time: 549.9026s (1.4 batches/s)
#
# === Final Test Evaluation ===
# Final Test MSE Loss: 0.0
# Done. Check .//content/drive/MyDrive/out-gpu-v1-3 for weights.

# %%
# !mkdir /content/drive/MyDrive/cuda_ltss/weights
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/cuda_ltss/weights’: File exists

# %%
# !cp out/weights_epoch_1.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_1.bin

# %%
# !cp out/weights_epoch_2.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_2.bin
