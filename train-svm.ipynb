# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 267, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 267 (delta 79), reused 96 (delta 46), pack-reused 138 (from 1)
# Receiving objects: 100% (267/267), 169.83 MiB | 45.55 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /kaggle/working/cuda_ltss
# ltss_gpu.ipynb	     ltss_gpu_v2_1.ipynb  Report.ipynb
# ltss_gpu_v1_1.ipynb  ltss_gpu_v2.ipynb	  src
# ltss_gpu_v1_3.ipynb  README.md		  train_svm.ipynb

# %%
# !nvcc -std=c++17 -O3 \
    src/train_svm/train_svm.cpp \
    src/train_svm/gpu_autoencoder.cu \
    src/train_svm/svm.cpp \
    -I./include \
    -arch=sm_75 \
    --default-stream per-thread \
    -o train_svm_tool

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-14 13:43:29--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  75.4MB/s    in 2.2s
#
# 2025-12-14 13:43:32 (75.4 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !./train_svm_tool cifar-10-batches-bin src/weights/weights_gpu_v1_3.bin
# Out:
# Loading dataset...
# Successfully loaded weights from src/weights/weights_gpu_v1_3.bin
# ------------------------------------------------
# [TRAIN-SET] Start extracting features on GPU...
#
# [TRAIN-SET] Extraction Done.
#   - Count: 49984 samples
#   - Time:  19.5362 seconds
# ------------------------------------------------
# Converting to LIBSVM format...
# Conversion time: 4.9031s
# Training SVM (RBF Kernel)... This will take time on CPU.
# ..*
# optimization finished, #iter = 2982
# nu = 0.242524
# obj = -19495.210052, rho = 9.697910
# nSV = 2572, nBSV = 2289
# ....*
# optimization finished, #iter = 4974
# nu = 0.571798
# obj = -48344.815844, rho = 10.690057
# nSV = 5879, nBSV = 5564
# ..*.*
# optimization finished, #iter = 3100
# nu = 0.241095
# obj = -18535.072101, rho = 10.688010
# nSV = 2566, nBSV = 2262
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4658
# nu = 0.513369
# obj = -43975.941778, rho = 13.572025
# nSV = 5282, nBSV = 4979
# ...*.*
# optimization finished, #iter = 4225
# nu = 0.384861
# obj = -30326.108334, rho = 12.603057
# nSV = 4023, nBSV = 3673
# .
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2210
# nu = 0.179782
# obj = -14548.236411, rho = 10.978152
# nSV = 1898, nBSV = 1692
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4901
# nu = 0.534811
# obj = -45452.172521, rho = 23.973195
# nSV = 5525, nBSV = 5187
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4510
# nu = 0.467021
# obj = -38212.294315, rho = 18.885099
# nSV = 4830, nBSV = 4507
# ..*
# optimization finished, #iter = 2783
# nu = 0.225420
# obj = -18146.734591, rho = 8.651042
# nSV = 2390, nBSV = 2126
# ..*
# optimization finished, #iter = 2979
# nu = 0.264647
# obj = -21346.808895, rho = -2.076275
# nSV = 2767, nBSV = 2516
# ....
# WARNING: using -h 0 may be faster
# *..*
# optimization finished, #iter = 6222
# nu = 0.599739
# obj = -50867.575043, rho = -0.989749
# nSV = 6229, nBSV = 5771
# ..*.*
# optimization finished, #iter = 3304
# nu = 0.275327
# obj = -22307.803836, rho = 1.239245
# nSV = 2908, nBSV = 2606
# ...*.*
# optimization finished, #iter = 4269
# nu = 0.334043
# obj = -26669.770217, rho = 3.862977
# nSV = 3530, nBSV = 3146
# ...*
# optimization finished, #iter = 3827
# nu = 0.345876
# obj = -28777.783114, rho = 4.230364
# nSV = 3618, nBSV = 3313
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3844
# nu = 0.303468
# obj = -24471.215010, rho = 7.790560
# nSV = 3209, nBSV = 2872
# ..*.*
# optimization finished, #iter = 3700
# nu = 0.266198
# obj = -20948.176527, rho = 3.734563
# nSV = 2837, nBSV = 2495
# ...*.*
# optimization finished, #iter = 4067
# nu = 0.369850
# obj = -30801.025870, rho = 1.503181
# nSV = 3853, nBSV = 3521
# ..*.*
# optimization finished, #iter = 3035
# nu = 0.245733
# obj = -19051.185471, rho = 2.364968
# nSV = 2596, nBSV = 2311
# ....
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 5623
# nu = 0.725488
# obj = -63266.590398, rho = 4.233774
# nSV = 7395, nBSV = 7114
# ....*.*
# optimization finished, #iter = 5488
# nu = 0.538666
# obj = -46418.828192, rho = 6.758375
# nSV = 5554, nBSV = 5213
# ..*
# optimization finished, #iter = 2696
# nu = 0.253939
# obj = -21013.955528, rho = 4.912269
# nSV = 2655, nBSV = 2430
# ....*.*
# optimization finished, #iter = 5109
# nu = 0.553804
# obj = -48283.700181, rho = 17.373789
# nSV = 5698, nBSV = 5382
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4804
# nu = 0.537773
# obj = -45930.530722, rho = 11.914417
# nSV = 5532, nBSV = 5222
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3423
# nu = 0.327190
# obj = -27787.325458, rho = 3.197942
# nSV = 3390, nBSV = 3149
# ..*.*
# optimization finished, #iter = 3391
# nu = 0.270422
# obj = -21085.189446, rho = 1.494900
# nSV = 2862, nBSV = 2546
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3710
# nu = 0.286422
# obj = -21504.080482, rho = 3.668515
# nSV = 3046, nBSV = 2681
# ...*
# optimization finished, #iter = 3877
# nu = 0.340424
# obj = -28462.556131, rho = 6.097265
# nSV = 3544, nBSV = 3240
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3947
# nu = 0.287930
# obj = -22068.698008, rho = 7.606751
# nSV = 3074, nBSV = 2694
# ..*.*
# optimization finished, #iter = 3647
# nu = 0.254815
# obj = -19033.633080, rho = 4.270638
# nSV = 2737, nBSV = 2376
# ...*.*
# optimization finished, #iter = 4133
# nu = 0.365396
# obj = -29784.167979, rho = 2.866637
# nSV = 3817, nBSV = 3482
# ....*
# optimization finished, #iter = 4836
# nu = 0.494146
# obj = -41699.230550, rho = 4.222674
# nSV = 5103, nBSV = 4769
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3304
# nu = 0.307445
# obj = -25199.617048, rho = 3.431782
# nSV = 3211, nBSV = 2951
# ....*.*
# optimization finished, #iter = 5417
# nu = 0.588892
# obj = -52406.852555, rho = 13.774835
# nSV = 6045, nBSV = 5730
# ....*.*
# optimization finished, #iter = 5242
# nu = 0.576897
# obj = -50959.869676, rho = 5.884228
# nSV = 5922, nBSV = 5617
# ...*.*
# optimization finished, #iter = 4215
# nu = 0.415582
# obj = -35825.177513, rho = 0.024111
# nSV = 4295, nBSV = 4012
# ..*
# optimization finished, #iter = 2813
# nu = 0.226935
# obj = -17784.531203, rho = -0.690287
# nSV = 2385, nBSV = 2145
# ....*.*
# optimization finished, #iter = 5493
# nu = 0.496479
# obj = -41704.834826, rho = 5.992629
# nSV = 5140, nBSV = 4768
# ....*.*
# optimization finished, #iter = 5343
# nu = 0.526563
# obj = -44590.441119, rho = -0.220558
# nSV = 5442, nBSV = 5084
# ...*
# optimization finished, #iter = 3725
# nu = 0.317018
# obj = -25372.730341, rho = -1.550951
# nSV = 3342, nBSV = 3008
# ..*
# optimization finished, #iter = 2866
# nu = 0.258908
# obj = -21241.715636, rho = 0.900422
# nSV = 2712, nBSV = 2476
# ..*
# optimization finished, #iter = 2854
# nu = 0.229766
# obj = -18293.043714, rho = -2.266797
# nSV = 2422, nBSV = 2154
# ....*.*
# optimization finished, #iter = 5271
# nu = 0.565154
# obj = -48353.533815, rho = -7.121606
# nSV = 5804, nBSV = 5480
# .....*.*
# optimization finished, #iter = 6584
# nu = 0.784979
# obj = -71459.718225, rho = -10.717312
# nSV = 8008, nBSV = 7678
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3650
# nu = 0.319952
# obj = -26556.107306, rho = -4.870745
# nSV = 3341, nBSV = 3057
# ..*.*
# optimization finished, #iter = 3472
# nu = 0.281336
# obj = -22683.302390, rho = -0.015456
# nSV = 2958, nBSV = 2655
# Total nSV = 42878
# SVM Training time: 28601.8934s
# >> Saved SVM model to: cifar10_svm.model
# ------------------------------------------------
# [TEST-SET] Start extracting features on GPU...
#
# [TEST-SET] Extraction Done.
#   - Count: 9984 samples
#   - Time:  4.1211 seconds
# ------------------------------------------------
# Evaluating on Test Set...
#
# ==============================================
# FINAL RESULTS (No Scaling)
# ----------------------------------------------
# Total Runtime:   36121.2102s
# TEST ACCURACY:   59.5853%
# ==============================================
