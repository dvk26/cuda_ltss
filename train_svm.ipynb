# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 235 (delta 54), reused 75 (delta 32), pack-reused 138 (from 1)
# Receiving objects: 100% (235/235), 169.82 MiB | 22.98 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# ltss_gpu.ipynb	     ltss_gpu_v1_3.ipynb  ltss_gpu_v2.ipynb  Report.ipynb
# ltss_gpu_v1_1.ipynb  ltss_gpu_v2_1.ipynb  README.md	     src

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -std=c++17 -O3 \
    src/train_svm/train_svm.cpp \
    src/train_svm/gpu_autoencoder.cu \
    src/train_svm/svm.cpp \
    -I./include \
    -arch=sm_75 \
    --default-stream per-thread \
    -o train_svm_tool

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-12 16:20:42--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  42.3MB/s    in 4.2s
#
# 2025-12-12 16:20:46 (38.7 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !./train_svm_tool cifar-10-batches-bin src/weights/weights_gpu_v1_3.bin
# Out:
# Successfully loaded weights from src/weights/weights_gpu_v1_3.bin
# Extracting features...
#
# Extraction done. Total: 49984
# Preparing SVM training data format...
# Training SVM (This may take a while)...
# ..*
# optimization finished, #iter = 2982
# nu = 0.242524
# obj = -19495.210052, rho = 9.697910
# nSV = 2572, nBSV = 2289
# ....*
# optimization finished, #iter = 4974
# nu = 0.571798
# obj = -48344.815844, rho = 10.690057
# nSV = 5879, nBSV = 5564
# ..*.*
# optimization finished, #iter = 3100
# nu = 0.241095
# obj = -18535.072101, rho = 10.688010
# nSV = 2566, nBSV = 2262
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4658
# nu = 0.513369
# obj = -43975.941778, rho = 13.572025
# nSV = 5282, nBSV = 4979
# ...*.*
# optimization finished, #iter = 4225
# nu = 0.384861
# obj = -30326.108334, rho = 12.603057
# nSV = 4023, nBSV = 3673
# .
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2210
# nu = 0.179782
# obj = -14548.236411, rho = 10.978152
# nSV = 1898, nBSV = 1692
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4901
# nu = 0.534811
# obj = -45452.172521, rho = 23.973195
# nSV = 5525, nBSV = 5187
# ...
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4510
# nu = 0.467021
# obj = -38212.294315, rho = 18.885099
# nSV = 4830, nBSV = 4507
# ..*
# optimization finished, #iter = 2783
# nu = 0.225420
# obj = -18146.734591, rho = 8.651042
# nSV = 2390, nBSV = 2126
# ..*
# optimization finished, #iter = 2979
# nu = 0.264647
# obj = -21346.808895, rho = -2.076275
# nSV = 2767, nBSV = 2516
# ....
# WARNING: using -h 0 may be faster
# *..*
# optimization finished, #iter = 6222
# nu = 0.599739
# obj = -50867.575043, rho = -0.989749
# nSV = 6229, nBSV = 5771
# ..*.*
# optimization finished, #iter = 3304
# nu = 0.275327
# obj = -22307.803836, rho = 1.239245
# nSV = 2908, nBSV = 2606
# ...*.*
# optimization finished, #iter = 4269
# nu = 0.334043
# obj = -26669.770217, rho = 3.862977
# nSV = 3530, nBSV = 3146
# ...*
# optimization finished, #iter = 3827
# nu = 0.345876
# obj = -28777.783114, rho = 4.230364
# nSV = 3618, nBSV = 3313
# ..
# WARNING: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3844
# nu = 0.303468
# obj = -24471.215010, rho = 7.790560
# nSV = 3209, nBSV = 2872
# ..*.*
# optimization finished, #iter = 3700
# nu = 0.266198
# obj = -20948.176527, rho = 3.734563
# nSV = 2837, nBSV = 2495

# %%
# !mkdir /content/drive/MyDrive/cuda_ltss/weights
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/cuda_ltss/weights’: File exists

# %%
# !cp out/weights_epoch_1.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_1.bin

# %%
# !cp out/weights_epoch_2.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_2.bin
