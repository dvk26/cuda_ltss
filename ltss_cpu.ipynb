# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 13 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 8.25 KiB | 8.25 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# ltss_cpu.ipynb	src

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-11-24 14:47:13--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  44.3MB/s    in 4.0s
#
# 2025-11-24 14:47:17 (40.5 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !g++ -std=c++17 -O3 -march=native -ffast-math -DNDEBUG src/*.cpp -o autoencoder

# %%
# !./autoencoder cifar-10-batches-bin
# Out:
# Loading CIFAR-10...
# Total images: 60000 (train 50000, test 10000)
#
# === DEBUG MODE: Running with 1 batch only ===
#
# Epoch 1 | train_loss=0.230934 | time=35.3213s
# Epoch 2 | train_loss=0.142761 | time=35.1432s
# Epoch 3 | train_loss=0.113931 | time=35.1096s
# Epoch 4 | train_loss=0.126957 | time=35.3471s
# Epoch 5 | train_loss=0.122531 | time=34.3187s
#
# (Skipping test evaluation in debug mode)
# Done. Check ./out/*.ppm
