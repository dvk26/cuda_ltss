# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# %cd cuda_ltss
# !ls
# Out:
# cuda_ltss  drive  sample_data
# /content/cuda_ltss
# autoencoder	      cifar-10-binary.tar.gz  out  src_v2
# cifar-10-batches-bin  ltss_cpu.ipynb	      src

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 102 (delta 54), reused 73 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 32.09 KiB | 4.01 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# ltss_cpu.ipynb	src  src_v2

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Out:
# --2025-12-06 14:07:31--  https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: ‘cifar-10-binary.tar.gz’
#
# cifar-10-binary.tar 100%[===================>] 162.17M  33.7MB/s    in 4.8s
#
# 2025-12-06 14:07:36 (33.5 MB/s) - ‘cifar-10-binary.tar.gz’ saved [170052171/170052171]

# %%
# !tar -xvf cifar-10-binary.tar.gz
# Out:
# cifar-10-batches-bin/
# cifar-10-batches-bin/data_batch_1.bin
# cifar-10-batches-bin/batches.meta.txt
# cifar-10-batches-bin/data_batch_3.bin
# cifar-10-batches-bin/data_batch_4.bin
# cifar-10-batches-bin/test_batch.bin
# cifar-10-batches-bin/readme.html
# cifar-10-batches-bin/data_batch_5.bin
# cifar-10-batches-bin/data_batch_2.bin

# %%
# !g++ -std=c++17 -O3 -march=native -ffast-math -DNDEBUG src/*.cpp -o autoencoder

# %%
# !./autoencoder cifar-10-batches-bin
# Out:
# Loading CIFAR-10...
# Total images: 2400 (train 2000, test 400)
#
# === NON-DEBUG MODE ===
#
# [Epoch 1] batch 16/63
# [Epoch 1] batch 32/63
# [Epoch 1] batch 48/63
# Epoch 1 | train_loss=0.085777 | time=1637.74s
# [Epoch 2] batch 16/63
# [Epoch 2] batch 32/63
# [Epoch 2] batch 48/63
# Epoch 2 | train_loss=0.0552302 | time=1626.73s
# [Epoch 3] batch 16/63
# [Epoch 3] batch 32/63
# [Epoch 3] batch 48/63
# Epoch 3 | train_loss=0.046219 | time=1627.96s
# [Epoch 4] batch 16/63
# [Epoch 4] batch 32/63
# [Epoch 4] batch 48/63
# Epoch 4 | train_loss=0.0412841 | time=1631.69s
# [Epoch 5] batch 16/63
# [Epoch 5] batch 32/63
# [Epoch 5] batch 48/63
# Epoch 5 | train_loss=0.0380062 | time=1630.69s
# [Epoch 6] batch 16/63
# [Epoch 6] batch 32/63
# [Epoch 6] batch 48/63
# Epoch 6 | train_loss=0.0356415 | time=1612.6s
# [Epoch 7] batch 16/63
# [Epoch 7] batch 32/63
# [Epoch 7] batch 48/63
# Epoch 7 | train_loss=0.0338141 | time=1605.04s
# [Epoch 8] batch 16/63
# [Epoch 8] batch 32/63
# [Epoch 8] batch 48/63
# Epoch 8 | train_loss=0.0323425 | time=1602s
# [Epoch 9] batch 16/63
# [Epoch 9] batch 32/63
# [Epoch 9] batch 48/63
# Epoch 9 | train_loss=0.0310797 | time=1622.44s
# [Epoch 10] batch 16/63
# [Epoch 10] batch 32/63
# [Epoch 10] batch 48/63
# Epoch 10 | train_loss=0.030021 | time=1622.72s
# [Epoch 11] batch 16/63
# [Epoch 11] batch 32/63
# [Epoch 11] batch 48/63
# Epoch 11 | train_loss=0.029149 | time=1614.02s
# [Epoch 12] batch 16/63
# [Epoch 12] batch 32/63
# [Epoch 12] batch 48/63
# Epoch 12 | train_loss=0.0283249 | time=1609.94s
# [Epoch 13] batch 16/63
# [Epoch 13] batch 32/63
# [Epoch 13] batch 48/63
# Epoch 13 | train_loss=0.0276652 | time=1618.67s
# [Epoch 14] batch 16/63
# [Epoch 14] batch 32/63
# [Epoch 14] batch 48/63
# Epoch 14 | train_loss=0.0270219 | time=1617.17s
# [Epoch 15] batch 16/63
# [Epoch 15] batch 32/63
# [Epoch 15] batch 48/63
# Epoch 15 | train_loss=0.0264206 | time=1630.12s
# [Epoch 16] batch 16/63
# [Epoch 16] batch 32/63
# [Epoch 16] batch 48/63
# Epoch 16 | train_loss=0.0259783 | time=1627.63s
# [Epoch 17] batch 16/63
# [Epoch 17] batch 32/63
# [Epoch 17] batch 48/63
# Epoch 17 | train_loss=0.0254708 | time=1617.07s
# [Epoch 18] batch 16/63
# [Epoch 18] batch 32/63
# [Epoch 18] batch 48/63
# Epoch 18 | train_loss=0.0250664 | time=1609.44s
# [Epoch 19] batch 16/63
# [Epoch 19] batch 32/63
# [Epoch 19] batch 48/63
# Epoch 19 | train_loss=0.024666 | time=1619.08s
# [Epoch 20] batch 16/63
# [Epoch 20] batch 32/63
# [Epoch 20] batch 48/63
# Epoch 20 | train_loss=0.0242453 | time=1619.44s
#
# === Final Test Evaluation ===
# Final test_loss=0.0242968
# Done. Check ./out/*.ppm

# %%
from google.colab import drive
drive.mount('/content/drive')
