# %% [markdown]
# <a href="https://colab.research.google.com/github/dvk26/cuda_ltss/blob/main/ltss_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dvk26/cuda_ltss.git
# Out:
# Cloning into 'cuda_ltss'...
# remote: Enumerating objects: 138, done.
# remote: Total 138 (delta 0), reused 0 (delta 0), pack-reused 138 (from 1)
# Receiving objects: 100% (138/138), 161.76 MiB | 3.58 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Updating files: 100% (28/28), done.

# %%
# %cd cuda_ltss
# !ls
# Out:
# /content/cuda_ltss
# cifar-10-batches-bin  ltss_cpu.ipynb  src  src_stage2  src_v2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -std=c++17 -O2 \
    src_stage2/main.cu \
    src_stage2/gpu_autoencoder.cu \
    -I./src_stage2 \
    -arch=sm_75 \
    -o autoencoder_gpu
# Out:
# src_stage2/gpu_autoencoder.cu(638): warning #177-D: variable "shm" was declared but never referenced
#           size_t shm = BS * sizeof(float);
#                  ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# src_stage2/gpu_autoencoder.cu(961): warning #550-D: variable "loss_dummy" was set but never used
#       float loss_dummy;
#             ^

# %%
# !./autoencoder_gpu
# Out:
# Epoch 0 done. Avg loss=0.280119, time=21085.3 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_000.bin
# Epoch 1 done. Avg loss=0.252134, time=21339.2 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_001.bin
# Epoch 2 done. Avg loss=0.227976, time=21757.8 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_002.bin
# Epoch 3 done. Avg loss=0.2064, time=22187.5 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_003.bin
# Epoch 4 done. Avg loss=0.18681, time=22679.9 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_004.bin
# Epoch 5 done. Avg loss=0.168959, time=23166.8 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_005.bin
# Epoch 6 done. Avg loss=0.152743, time=23012.8 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_006.bin
# Epoch 7 done. Avg loss=0.13824, time=22779.9 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_007.bin
# Epoch 8 done. Avg loss=0.125478, time=22860.3 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_008.bin
# Epoch 9 done. Avg loss=0.114459, time=23017.6 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_009.bin
# Epoch 10 done. Avg loss=0.105162, time=22907.4 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_010.bin
# Epoch 11 done. Avg loss=0.0975017, time=22861.5 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_011.bin
# Epoch 12 done. Avg loss=0.0913457, time=22887.8 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_012.bin
# Epoch 13 done. Avg loss=0.0865106, time=22921.4 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_013.bin
# Epoch 14 done. Avg loss=0.0827911, time=22949 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_014.bin
# Epoch 15 done. Avg loss=0.0799791, time=22952.5 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_015.bin
# Epoch 16 done. Avg loss=0.0778805, time=22942.8 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_016.bin
# Epoch 17 done. Avg loss=0.076329, time=22933 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_017.bin
# Epoch 18 done. Avg loss=0.0751864, time=22915.7 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_018.bin
# Epoch 19 done. Avg loss=0.0743438, time=22904.9 ms
#   Saved weights to: /content/drive/MyDrive/ltss_autoencoder_gpu_out/weights_epoch_019.bin

# %%
# !mkdir /content/drive/MyDrive/cuda_ltss/weights
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/cuda_ltss/weights’: File exists

# %%
# !cp out/weights_epoch_1.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_1.bin

# %%
# !cp out/weights_epoch_2.bin /content/drive/MyDrive/cuda_ltss/weights/weights_epoch_2.bin
